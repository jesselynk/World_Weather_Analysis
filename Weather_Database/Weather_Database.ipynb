# %%
#Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of 2,000 random longitude and latitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the lats and lngs to a list. 
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#Create URL for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c08c33e7f1895c9e5106246421673330

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c08c33e7f1895c9e5106246421673330&q=Boston

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yinchuan
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | hofn
# Processing Record 5 of Set 1 | fort saint james
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | aktau
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | xichang
# Processing Record 13 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | straz pod ralskem
# Processing Record 16 of Set 1 | esqueda
# Processing Record 17 of Set 1 | cansahcab
# Processing Record 18 of Set 1 | rio gallegos
# Processing Record 19 of Set 1 | cayenne
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | koumac
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | mahon
# Processing Record 26 of Set 1 | plettenberg bay
# Processing Record 27 of Set 1 | whitianga
# Processing Record 28 of Set 1 | liberia
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | botou
# Processing Record 33 of Set 1 | petatlan
# Processing Record 34 of Set 1 | port hardy
# Processing Record 35 of Set 1 | bulgan
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | shache
# Processing Record 39 of Set 1 | masuguru
# Processing Record 40 of Set 1 | mgandu
# Processing Record 41 of Set 1 | stornoway
# Processing Record 42 of Set 1 | sioux lookout
# Processing Record 43 of Set 1 | andenes
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | itapirapua
# Processing Record 46 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 1 | vila franca do campo
# Processing Record 48 of Set 1 | kidal
# Processing Record 49 of Set 1 | nome
# Processing Record 50 of Set 1 | esperance
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 2 | kalevala
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | krugersdorp
# Processing Record 6 of Set 2 | ati
# Processing Record 7 of Set 2 | mondolfo
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | remanso
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | salinopolis
# Processing Record 13 of Set 2 | mandera
# Processing Record 14 of Set 2 | dzidzantun
# Processing Record 15 of Set 2 | simga
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | launceston
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | nantucket
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | yaan
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | lavrentiya
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | esfarayen
# Processing Record 29 of Set 2 | charters towers
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | luena
# Processing Record 33 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | washington
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | lebanon
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | kingisepp
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | rocha
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | yulara
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | salalah
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 0 of Set 3 | atar
# Processing Record 1 of Set 3 | stolin
# Processing Record 2 of Set 3 | comodoro rivadavia
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | yenagoa
# Processing Record 7 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 8 of Set 3 | sobolevo
# Processing Record 9 of Set 3 | pedernales
# Processing Record 10 of Set 3 | adrar
# Processing Record 11 of Set 3 | ixtapa
# Processing Record 12 of Set 3 | kota belud
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | champerico
# Processing Record 15 of Set 3 | beberibe
# Processing Record 16 of Set 3 | villa bruzual
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | yumen
# Processing Record 19 of Set 3 | houston
# Processing Record 20 of Set 3 | dalvik
# Processing Record 21 of Set 3 | kavieng
# Processing Record 22 of Set 3 | port lincoln
# Processing Record 23 of Set 3 | roscommon
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | sayyan
# Processing Record 28 of Set 3 | progreso
# Processing Record 29 of Set 3 | mountain home
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | lima
# Processing Record 33 of Set 3 | mlonggo
# Processing Record 34 of Set 3 | hobart
# Processing Record 35 of Set 3 | klaksvik
# Processing Record 36 of Set 3 | atikokan
# Processing Record 37 of Set 3 | verkhnevilyuysk
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | camargo
# Processing Record 41 of Set 3 | marsa matruh
# Processing Record 42 of Set 3 | whithorn
# Processing Record 43 of Set 3 | bako
# Processing Record 44 of Set 3 | leh
# Processing Record 45 of Set 3 | tshane
# Processing Record 46 of Set 3 | arti
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | merauke
# Processing Record 0 of Set 4 | luderitz
# Processing Record 1 of Set 4 | mingshui
# Processing Record 2 of Set 4 | gizo
# Processing Record 3 of Set 4 | afua
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | jalpan
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | acapulco
# Processing Record 10 of Set 4 | saint-augustin
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | dongying
# Processing Record 14 of Set 4 | melo
# Processing Record 15 of Set 4 | kawalu
# Processing Record 16 of Set 4 | basco
# Processing Record 17 of Set 4 | cabo san lucas
# Processing Record 18 of Set 4 | vaini
# Processing Record 19 of Set 4 | estelle
# Processing Record 20 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 4 | burica
# City not found. Skipping...
# Processing Record 22 of Set 4 | sur
# Processing Record 23 of Set 4 | drayton valley
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | roanoke rapids
# Processing Record 26 of Set 4 | gabu
# Processing Record 27 of Set 4 | cockburn town
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | adiake
# Processing Record 30 of Set 4 | xining
# Processing Record 31 of Set 4 | itarema
# Processing Record 32 of Set 4 | tres arroyos
# Processing Record 33 of Set 4 | ribeira grande
# Processing Record 34 of Set 4 | belmonte
# Processing Record 35 of Set 4 | abha
# Processing Record 36 of Set 4 | rexburg
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | qaqortoq
# Processing Record 39 of Set 4 | tuatapere
# Processing Record 40 of Set 4 | hermanus
# Processing Record 41 of Set 4 | riyadh
# Processing Record 42 of Set 4 | touros
# Processing Record 43 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 4 | tilichiki
# Processing Record 45 of Set 4 | puyo
# Processing Record 46 of Set 4 | honiara
# Processing Record 47 of Set 4 | fort frances
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | arkhara
# Processing Record 0 of Set 5 | georgetown
# Processing Record 1 of Set 5 | bongor
# Processing Record 2 of Set 5 | teahupoo
# Processing Record 3 of Set 5 | kampong thum
# Processing Record 4 of Set 5 | viedma
# Processing Record 5 of Set 5 | sambir
# Processing Record 6 of Set 5 | jijiga
# Processing Record 7 of Set 5 | svetlogorsk
# Processing Record 8 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 5 | khani
# Processing Record 10 of Set 5 | guatire
# Processing Record 11 of Set 5 | portland
# Processing Record 12 of Set 5 | valparaiso
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | martapura
# Processing Record 15 of Set 5 | yima
# Processing Record 16 of Set 5 | maniitsoq
# Processing Record 17 of Set 5 | kiunga
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | chicama
# Processing Record 20 of Set 5 | acarau
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | coahuayana
# Processing Record 25 of Set 5 | ye
# City not found. Skipping...
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | botshabelo
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | perleberg
# Processing Record 31 of Set 5 | dingle
# Processing Record 32 of Set 5 | guaira
# Processing Record 33 of Set 5 | ulyanovo
# City not found. Skipping...
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | hisor
# Processing Record 37 of Set 5 | port elizabeth
# Processing Record 38 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | udachnyy
# Processing Record 41 of Set 5 | puerto narino
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | tateyama
# Processing Record 44 of Set 5 | lianzhou
# Processing Record 45 of Set 5 | kloulklubed
# Processing Record 46 of Set 5 | longyearbyen
# Processing Record 47 of Set 5 | clyde river
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | beloha
# Processing Record 0 of Set 6 | ha tinh
# Processing Record 1 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | yurginskoye
# Processing Record 4 of Set 6 | namibe
# Processing Record 5 of Set 6 | mizdah
# Processing Record 6 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 6 | semporna
# Processing Record 8 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 6 | kudat
# Processing Record 10 of Set 6 | easton
# Processing Record 11 of Set 6 | noormarkku
# Processing Record 12 of Set 6 | wattegama
# Processing Record 13 of Set 6 | severo-kurilsk
# Processing Record 14 of Set 6 | houma
# Processing Record 15 of Set 6 | pangoa
# Processing Record 16 of Set 6 | concordia
# Processing Record 17 of Set 6 | zaria
# Processing Record 18 of Set 6 | matagami
# Processing Record 19 of Set 6 | tessalit
# Processing Record 20 of Set 6 | cache creek
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | brazzaville
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | yakeshi
# Processing Record 26 of Set 6 | portobelo
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | senno
# Processing Record 29 of Set 6 | mawlaik
# Processing Record 30 of Set 6 | port blair
# Processing Record 31 of Set 6 | gbarnga
# Processing Record 32 of Set 6 | baoro
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | pacific grove
# Processing Record 35 of Set 6 | mocuba
# Processing Record 36 of Set 6 | waingapu
# Processing Record 37 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 6 | saryagash
# Processing Record 39 of Set 6 | muros
# Processing Record 40 of Set 6 | ashqelon
# Processing Record 41 of Set 6 | natal
# Processing Record 42 of Set 6 | alvaraes
# Processing Record 43 of Set 6 | mapiripan
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | gazli
# Processing Record 46 of Set 6 | namatanai
# Processing Record 47 of Set 6 | ostrovnoy
# Processing Record 48 of Set 6 | pavlodar
# Processing Record 49 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 0 of Set 7 | den helder
# Processing Record 1 of Set 7 | la ronge
# Processing Record 2 of Set 7 | tupelo
# Processing Record 3 of Set 7 | mumbwa
# Processing Record 4 of Set 7 | ambulu
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | odweyne
# Processing Record 7 of Set 7 | roald
# Processing Record 8 of Set 7 | wakema
# Processing Record 9 of Set 7 | maraba
# Processing Record 10 of Set 7 | moerai
# Processing Record 11 of Set 7 | hualmay
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | bonavista
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | nuevo progreso
# Processing Record 16 of Set 7 | okhotsk
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | chapleau
# Processing Record 19 of Set 7 | harper
# Processing Record 20 of Set 7 | vega de alatorre
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | vigrestad
# Processing Record 23 of Set 7 | andapa
# Processing Record 24 of Set 7 | mehamn
# Processing Record 25 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 7 | norman wells
# Processing Record 27 of Set 7 | bengkulu
# Processing Record 28 of Set 7 | mar del plata
# Processing Record 29 of Set 7 | sabya
# Processing Record 30 of Set 7 | kenai
# Processing Record 31 of Set 7 | navolato
# Processing Record 32 of Set 7 | erdenet
# Processing Record 33 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 7 | beihai
# Processing Record 35 of Set 7 | bintulu
# Processing Record 36 of Set 7 | gilgit
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | murray bridge
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | port-cartier
# Processing Record 41 of Set 7 | hukuntsi
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | karratha
# Processing Record 44 of Set 7 | ostersund
# Processing Record 45 of Set 7 | fairview
# Processing Record 46 of Set 7 | quesnel
# Processing Record 47 of Set 7 | fuling
# Processing Record 48 of Set 7 | palauig
# Processing Record 49 of Set 7 | sabaudia
# Processing Record 0 of Set 8 | isangel
# Processing Record 1 of Set 8 | shingu
# Processing Record 2 of Set 8 | pasighat
# Processing Record 3 of Set 8 | vikramasingapuram
# Processing Record 4 of Set 8 | dobrinka
# Processing Record 5 of Set 8 | seddon
# Processing Record 6 of Set 8 | solnechnyy
# Processing Record 7 of Set 8 | albanel
# Processing Record 8 of Set 8 | buseresere
# Processing Record 9 of Set 8 | verkhnyaya khava
# Processing Record 10 of Set 8 | loreto
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | alice town
# Processing Record 13 of Set 8 | jiayuguan
# Processing Record 14 of Set 8 | raga
# Processing Record 15 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 8 | araouane
# Processing Record 17 of Set 8 | marovoay
# Processing Record 18 of Set 8 | carballo
# Processing Record 19 of Set 8 | mezen
# Processing Record 20 of Set 8 | lorengau
# Processing Record 21 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 8 | filadelfia
# Processing Record 23 of Set 8 | villiers
# Processing Record 24 of Set 8 | usinsk
# Processing Record 25 of Set 8 | verkhoshizhemye
# Processing Record 26 of Set 8 | aquiraz
# Processing Record 27 of Set 8 | llanes
# Processing Record 28 of Set 8 | lewisville
# Processing Record 29 of Set 8 | varna
# Processing Record 30 of Set 8 | dzilam gonzalez
# Processing Record 31 of Set 8 | zonguldak
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | raudeberg
# Processing Record 35 of Set 8 | broome
# Processing Record 36 of Set 8 | cidreira
# Processing Record 37 of Set 8 | axim
# Processing Record 38 of Set 8 | baykit
# Processing Record 39 of Set 8 | port moresby
# Processing Record 40 of Set 8 | dawei
# Processing Record 41 of Set 8 | takaka
# Processing Record 42 of Set 8 | tarko-sale
# Processing Record 43 of Set 8 | olafsvik
# Processing Record 44 of Set 8 | kabugao
# Processing Record 45 of Set 8 | danbury
# Processing Record 46 of Set 8 | kodiak
# Processing Record 47 of Set 8 | andrushivka
# Processing Record 48 of Set 8 | kyaikto
# Processing Record 49 of Set 8 | thinadhoo
# Processing Record 0 of Set 9 | la florida
# Processing Record 1 of Set 9 | sorland
# Processing Record 2 of Set 9 | koutiala
# Processing Record 3 of Set 9 | kahului
# Processing Record 4 of Set 9 | sault sainte marie
# Processing Record 5 of Set 9 | usakos
# Processing Record 6 of Set 9 | cheremnoye
# Processing Record 7 of Set 9 | dunedin
# Processing Record 8 of Set 9 | srednekolymsk
# Processing Record 9 of Set 9 | torbay
# Processing Record 10 of Set 9 | nkan
# Processing Record 11 of Set 9 | vestmannaeyjar
# Processing Record 12 of Set 9 | waipawa
# Processing Record 13 of Set 9 | bud
# Processing Record 14 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 9 | vila velha
# Processing Record 16 of Set 9 | rovaniemi
# Processing Record 17 of Set 9 | aklavik
# Processing Record 18 of Set 9 | coquimbo
# Processing Record 19 of Set 9 | wakkanai
# Processing Record 20 of Set 9 | sibu
# Processing Record 21 of Set 9 | markova
# Processing Record 22 of Set 9 | piranshahr
# Processing Record 23 of Set 9 | suez
# Processing Record 24 of Set 9 | xapuri
# Processing Record 25 of Set 9 | allapalli
# Processing Record 26 of Set 9 | milos
# Processing Record 27 of Set 9 | pasni
# Processing Record 28 of Set 9 | kibre mengist
# Processing Record 29 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | zhangye
# Processing Record 32 of Set 9 | taltal
# Processing Record 33 of Set 9 | huamachuco
# Processing Record 34 of Set 9 | vadso
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | puerto madero
# Processing Record 37 of Set 9 | mangrol
# Processing Record 38 of Set 9 | rundu
# Processing Record 39 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 9 | porto velho
# Processing Record 41 of Set 9 | hachinohe
# Processing Record 42 of Set 9 | morozovsk
# Processing Record 43 of Set 9 | batangafo
# Processing Record 44 of Set 9 | suwannaphum
# Processing Record 45 of Set 9 | hammerfest
# Processing Record 46 of Set 9 | calabozo
# Processing Record 47 of Set 9 | naze
# Processing Record 48 of Set 9 | muzaffarabad
# Processing Record 49 of Set 9 | beatrice
# Processing Record 0 of Set 10 | lagoa
# Processing Record 1 of Set 10 | baton rouge
# Processing Record 2 of Set 10 | mpongwe
# Processing Record 3 of Set 10 | prince albert
# Processing Record 4 of Set 10 | a coruna
# Processing Record 5 of Set 10 | ahuimanu
# Processing Record 6 of Set 10 | tocopilla
# Processing Record 7 of Set 10 | aras
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | quito
# Processing Record 10 of Set 10 | sao filipe
# Processing Record 11 of Set 10 | yamandu
# Processing Record 12 of Set 10 | walvis bay
# Processing Record 13 of Set 10 | alofi
# Processing Record 14 of Set 10 | cruzeiro do sul
# Processing Record 15 of Set 10 | aasiaat
# Processing Record 16 of Set 10 | abu dhabi
# Processing Record 17 of Set 10 | shalinskoye
# Processing Record 18 of Set 10 | biltine
# Processing Record 19 of Set 10 | saint-paul
# Processing Record 20 of Set 10 | vestmanna
# Processing Record 21 of Set 10 | mikumi
# Processing Record 22 of Set 10 | puerto del rosario
# Processing Record 23 of Set 10 | nicoya
# Processing Record 24 of Set 10 | xingtai
# Processing Record 25 of Set 10 | mega
# Processing Record 26 of Set 10 | wagar
# Processing Record 27 of Set 10 | road town
# Processing Record 28 of Set 10 | nuuk
# Processing Record 29 of Set 10 | umm kaddadah
# Processing Record 30 of Set 10 | daitari
# Processing Record 31 of Set 10 | coari
# Processing Record 32 of Set 10 | korla
# Processing Record 33 of Set 10 | swan hill
# Processing Record 34 of Set 10 | komsomolskiy
# Processing Record 35 of Set 10 | enid
# Processing Record 36 of Set 10 | panzhihua
# Processing Record 37 of Set 10 | gannan
# Processing Record 38 of Set 10 | scarborough
# Processing Record 39 of Set 10 | murzzuschlag
# Processing Record 40 of Set 10 | high level
# Processing Record 41 of Set 10 | sabzevar
# Processing Record 42 of Set 10 | mongoumba
# Processing Record 43 of Set 10 | teya
# Processing Record 44 of Set 10 | guanica
# Processing Record 45 of Set 10 | puerto quijarro
# Processing Record 46 of Set 10 | bukama
# Processing Record 47 of Set 10 | vallentuna
# Processing Record 48 of Set 10 | ordynskoye
# Processing Record 49 of Set 10 | egvekinot
# Processing Record 0 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 11 | cururupu
# Processing Record 2 of Set 11 | bella union
# Processing Record 3 of Set 11 | general roca
# Processing Record 4 of Set 11 | volchikha
# Processing Record 5 of Set 11 | santa rosalia
# Processing Record 6 of Set 11 | yeppoon
# Processing Record 7 of Set 11 | jinchang
# Processing Record 8 of Set 11 | sechura
# Processing Record 9 of Set 11 | biharamulo
# Processing Record 10 of Set 11 | kuznechnoye
# Processing Record 11 of Set 11 | beringovskiy
# Processing Record 12 of Set 11 | manasa
# Processing Record 13 of Set 11 | oktyabrskoye
# Processing Record 14 of Set 11 | atasu
# Processing Record 15 of Set 11 | sao joao da barra
# Processing Record 16 of Set 11 | rio grande
# Processing Record 17 of Set 11 | ramasukha
# City not found. Skipping...
# Processing Record 18 of Set 11 | neryungri
# Processing Record 19 of Set 11 | bontang
# Processing Record 20 of Set 11 | birao
# Processing Record 21 of Set 11 | fukagawa
# Processing Record 22 of Set 11 | ust-koksa
# Processing Record 23 of Set 11 | bilibino
# Processing Record 24 of Set 11 | inegol
# Processing Record 25 of Set 11 | grand forks
# Processing Record 26 of Set 11 | parainen
# Processing Record 27 of Set 11 | cap malheureux
# Processing Record 28 of Set 11 | altagracia de orituco
# Processing Record 29 of Set 11 | ilan
# Processing Record 30 of Set 11 | varhaug
# Processing Record 31 of Set 11 | kribi
# Processing Record 32 of Set 11 | tongliao
# Processing Record 33 of Set 11 | akureyri
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | fairbanks
# Processing Record 36 of Set 11 | lazaro cardenas
# Processing Record 37 of Set 11 | alta floresta
# Processing Record 38 of Set 11 | sanmenxia
# Processing Record 39 of Set 11 | tambura
# Processing Record 40 of Set 11 | kasese
# Processing Record 41 of Set 11 | maarianhamina
# Processing Record 42 of Set 11 | west monroe
# Processing Record 43 of Set 11 | porgera
# Processing Record 44 of Set 11 | conde
# Processing Record 45 of Set 11 | zhuanghe
# Processing Record 46 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 11 | bauta
# Processing Record 48 of Set 11 | waddan
# Processing Record 49 of Set 11 | at-bashi
# Processing Record 0 of Set 12 | muisne
# Processing Record 1 of Set 12 | nieuw nickerie
# Processing Record 2 of Set 12 | vostok
# Processing Record 3 of Set 12 | toamasina
# Processing Record 4 of Set 12 | mikhaylovka
# Processing Record 5 of Set 12 | brainerd
# Processing Record 6 of Set 12 | tire
# Processing Record 7 of Set 12 | salta
# Processing Record 8 of Set 12 | cairns
# Processing Record 9 of Set 12 | husavik
# Processing Record 10 of Set 12 | galveston
# Processing Record 11 of Set 12 | margate
# Processing Record 12 of Set 12 | le port
# Processing Record 13 of Set 12 | carupano
# Processing Record 14 of Set 12 | banes
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | bulaevo
# Processing Record 17 of Set 12 | prieska
# Processing Record 18 of Set 12 | bilma
# Processing Record 19 of Set 12 | bati
# Processing Record 20 of Set 12 | vitim
# Processing Record 21 of Set 12 | flin flon
# Processing Record 22 of Set 12 | matto
# City not found. Skipping...
# Processing Record 23 of Set 12 | liwale
# Processing Record 24 of Set 12 | lake havasu city
# Processing Record 25 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 12 | rondonopolis
# Processing Record 27 of Set 12 | tautira
# Processing Record 28 of Set 12 | logan
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | arlit
# Processing Record 31 of Set 12 | graciano sanchez
# Processing Record 32 of Set 12 | brenham
# Processing Record 33 of Set 12 | hanzhong
# Processing Record 34 of Set 12 | henties bay
# Processing Record 35 of Set 12 | cuamba
# Processing Record 36 of Set 12 | flinders
# Processing Record 37 of Set 12 | ugoofaaru
# Processing Record 38 of Set 12 | columbus
# Processing Record 39 of Set 12 | zemio
# Processing Record 40 of Set 12 | rizomilos
# Processing Record 41 of Set 12 | dudinka
# Processing Record 42 of Set 12 | derzhavinsk
# Processing Record 43 of Set 12 | okha
# Processing Record 44 of Set 12 | nhulunbuy
# Processing Record 45 of Set 12 | sumbe
# Processing Record 46 of Set 12 | prince rupert
# Processing Record 47 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 12 | aguimes
# Processing Record 49 of Set 12 | kolokani
# Processing Record 0 of Set 13 | gappal
# Processing Record 1 of Set 13 | pacifica
# Processing Record 2 of Set 13 | lamu
# Processing Record 3 of Set 13 | tura
# Processing Record 4 of Set 13 | lata
# Processing Record 5 of Set 13 | hokitika
# Processing Record 6 of Set 13 | lanycsok
# Processing Record 7 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 13 | kysyl-syr
# Processing Record 9 of Set 13 | yekimovichi
# Processing Record 10 of Set 13 | gobabis
# Processing Record 11 of Set 13 | sivas
# Processing Record 12 of Set 13 | haimen
# Processing Record 13 of Set 13 | acajutla
# Processing Record 14 of Set 13 | cordoba
# Processing Record 15 of Set 13 | saint-francois
# Processing Record 16 of Set 13 | barkhan
# Processing Record 17 of Set 13 | kharp
# Processing Record 18 of Set 13 | pyshchug
# Processing Record 19 of Set 13 | haines junction
# Processing Record 20 of Set 13 | le moule
# Processing Record 21 of Set 13 | denpasar
# Processing Record 22 of Set 13 | kimbe
# Processing Record 23 of Set 13 | staryy nadym
# Processing Record 24 of Set 13 | am timan
# Processing Record 25 of Set 13 | jasper
# Processing Record 26 of Set 13 | nipawin
# Processing Record 27 of Set 13 | paysandu
# Processing Record 28 of Set 13 | los llanos de aridane
# Processing Record 29 of Set 13 | avera
# Processing Record 30 of Set 13 | wanning
# Processing Record 31 of Set 13 | khandyga
# Processing Record 32 of Set 13 | stamsund
# City not found. Skipping...
# Processing Record 33 of Set 13 | morehead
# Processing Record 34 of Set 13 | churapcha
# Processing Record 35 of Set 13 | monrovia
# Processing Record 36 of Set 13 | auch
# Processing Record 37 of Set 13 | bubaque
# Processing Record 38 of Set 13 | taraza
# Processing Record 39 of Set 13 | hervey bay
# Processing Record 40 of Set 13 | takestan
# Processing Record 41 of Set 13 | shizunai
# Processing Record 42 of Set 13 | vallenar
# Processing Record 43 of Set 13 | pangnirtung
# Processing Record 44 of Set 13 | port augusta
# Processing Record 45 of Set 13 | sibolga
# Processing Record 46 of Set 13 | key west
# Processing Record 47 of Set 13 | yatou
# Processing Record 48 of Set 13 | nemuro
# Processing Record 49 of Set 13 | marawi
# Processing Record 0 of Set 14 | konstantinovka
# Processing Record 1 of Set 14 | laguna
# Processing Record 2 of Set 14 | porto novo
# Processing Record 3 of Set 14 | port keats
# Processing Record 4 of Set 14 | lakselv
# Processing Record 5 of Set 14 | havre-saint-pierre
# Processing Record 6 of Set 14 | vardo
# Processing Record 7 of Set 14 | moose factory
# Processing Record 8 of Set 14 | kaoma
# Processing Record 9 of Set 14 | pimentel
# Processing Record 10 of Set 14 | tevaitoa
# Processing Record 11 of Set 14 | luhyny
# Processing Record 12 of Set 14 | sangar
# Processing Record 13 of Set 14 | bar harbor
# Processing Record 14 of Set 14 | lanzhou
# Processing Record 15 of Set 14 | zhigalovo
# Processing Record 16 of Set 14 | lipetsk
# Processing Record 17 of Set 14 | ribnitz-damgarten
# Processing Record 18 of Set 14 | ndele
# Processing Record 19 of Set 14 | opuwo
# Processing Record 20 of Set 14 | san fernando
# Processing Record 21 of Set 14 | smithers
# Processing Record 22 of Set 14 | miyako
# Processing Record 23 of Set 14 | altay
# Processing Record 24 of Set 14 | neiafu
# Processing Record 25 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 14 | warrington
# Processing Record 27 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 28 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 14 | qui nhon
# Processing Record 30 of Set 14 | hami
# Processing Record 31 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 14 | narsaq
# Processing Record 33 of Set 14 | gopalpur
# Processing Record 34 of Set 14 | celestun
# Processing Record 35 of Set 14 | puerto escondido
# Processing Record 36 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 37 of Set 14 | turukhansk
# Processing Record 38 of Set 14 | chifeng
# Processing Record 39 of Set 14 | malanje
# Processing Record 40 of Set 14 | auki
# Processing Record 41 of Set 14 | fernley
# Processing Record 42 of Set 14 | manaure
# Processing Record 43 of Set 14 | poum
# Processing Record 44 of Set 14 | inirida
# Processing Record 45 of Set 14 | san quintin
# Processing Record 46 of Set 14 | minab
# Processing Record 47 of Set 14 | bangkal
# Processing Record 48 of Set 14 | bambanglipuro
# Processing Record 49 of Set 14 | san miguel
# Processing Record 0 of Set 15 | humaita
# Processing Record 1 of Set 15 | ereymentau
# Processing Record 2 of Set 15 | uarini
# Processing Record 3 of Set 15 | chancay
# Processing Record 4 of Set 15 | red bluff
# Processing Record 5 of Set 15 | aykhal
# Processing Record 6 of Set 15 | san pedro
# Processing Record 7 of Set 15 | tanggu
# Processing Record 8 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 15 | bowen
# Processing Record 10 of Set 15 | sindgi
# Processing Record 11 of Set 15 | ucluelet
# Processing Record 12 of Set 15 | rayong
# Processing Record 13 of Set 15 | saint-joseph
# Processing Record 14 of Set 15 | isoka
# Processing Record 15 of Set 15 | antofagasta
# Processing Record 16 of Set 15 | ballina
# Processing Record 17 of Set 15 | erenhot
# Processing Record 18 of Set 15 | youkounkoun
# Processing Record 19 of Set 15 | ilheus
# Processing Record 20 of Set 15 | skibotn
# Processing Record 21 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 15 | seydi
# Processing Record 23 of Set 15 | almaznyy
# Processing Record 24 of Set 15 | ngunguru
# Processing Record 25 of Set 15 | kieta
# Processing Record 26 of Set 15 | tamiahua
# Processing Record 27 of Set 15 | san andres
# Processing Record 28 of Set 15 | bairiki
# Processing Record 29 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 30 of Set 15 | muzhi
# Processing Record 31 of Set 15 | codrington
# Processing Record 32 of Set 15 | geraldton
# Processing Record 33 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 15 | takoradi
# Processing Record 35 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 15 | manaia
# Processing Record 37 of Set 15 | moba
# Processing Record 38 of Set 15 | pinyug
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          687
# Lat           687
# Lng           687
# Max Temp      687
# Humidity      687
# Cloudiness    687
# Wind Speed    687
# Country       687
# Date          687
# dtype: int64

# %%
city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            yinchuan  38.4681  106.2731     29.62        55          60
# 1             ushuaia -54.8000  -68.3000     59.00        51          75
# 2           cape town -33.9258   18.4232     75.00        64           0
# 3                hofn  64.2539  -15.2082     39.97        90         100
# 4    fort saint james  54.4333 -124.2500     29.98        90          92
# ..                ...      ...       ...       ...       ...         ...
# 682         geraldton -28.7667  114.6000     69.80        64           0
# 683          takoradi   4.8845   -1.7554     79.00        85           6
# 684            manaia -39.5500  174.1333     66.00        95           0
# 685              moba  33.2288  105.0179     26.56        85           0
# 686            pinyug  60.2510   47.7842    -19.44        88          14
#
#      Wind Speed Country        Date
# 0          9.31      CN  1610570506
# 1          5.75      AR  1610570326
# 2          6.91      ZA  1610570317
# 3         18.34      IS  1610570487
# 4          6.20      CA  1610570507
# ..          ...     ...         ...
# 682       10.36      AU  1610570432
# 683        8.23      GH  1610570477
# 684        1.01      NZ  1610570667
# 685        4.07      CN  1610570667
# 686        4.63      RU  1610570668
#
# [687 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
